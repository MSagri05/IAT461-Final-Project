# %% [markdown]
# <a href="https://colab.research.google.com/github/MSagri05/IAT461-Final-Project/blob/main/workplace_accommodation_analysis_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Workplace Accommodation Bias and Fulfillment Analysis
#
# **Course:** IAT 461
# **Final Project – Data Scientist Role**
# **Client:** Stin
# **Data Scientist:** Manmeet Sagri
#
# ## Project Overview
#
# This project analyzes a synthetic workplace accommodation dataset created for the Job Accommodation Network (JAN). The purpose of the initial exploratory data analysis is to evaluate three possible organizational strategies and determine whether accommodation outcomes are primarily influenced by cost or whether specific disability categories, departments, and HR reviewers experience disproportionate denial rates or implementation delays.
#
# The later modeling stage will predict accommodation approval status and implementation time while accounting for relevant employee, request, workplace, and cost-related variables.

# %% [markdown]
# ### importing the dataset from google drive

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 1. Environment Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %% [markdown]
# ## 2. Data Loading
#
# dataset is stored in google drive, so it can accessed even if runtime is disconnected

# %%
file_path = (
    "/content/drive/MyDrive/IAT461_Final_Project/"
    "data/workplace_accommodation_synthetic.csv"
)

try:
    df = pd.read_csv(file_path)
    print("Dataset loaded successfully.")
    print(f"Rows: {df.shape[0]}")
    print(f"Columns: {df.shape[1]}")
except FileNotFoundError:
    print("File not found. Check the folder and file names in Google Drive.")
# Out:
# Dataset loaded successfully.
# Rows: 260
# Columns: 16

# %%
df.head()
# Out:
#   request_id     disability_category accommodation_category  \
# 0   REQ-1000           Mental Health   Assistive technology
# 1   REQ-1001         Chronic Medical   Assistive technology
# 2   REQ-1002  Cognitive/Neurological      Communication aid
# 3   REQ-1003         Chronic Medical  Schedule modification
# 4   REQ-1004         Chronic Medical  Schedule modification
#
#    employee_tenure_years  hourly_wage_usd  has_college_degree  \
# 0                    4.3            22.46                   1
# 1                    5.6            21.83                   1
# 2                    7.5            26.43                   1
# 3                    1.6            20.24                   1
# 4                    2.3            25.84                   0
#
#    is_cost_incurred  accommodation_cost_usd request_severity_level  \
# 0                 0                    0.00                 Medium
# 1                 0                    0.00                    Low
# 2                 1                 2321.51                 Medium
# 3                 0                    0.00                    Low
# 4                 1                   79.80                    Low
#
#   remote_work_status   department hr_reviewer_id approval_status  \
# 0             Hybrid        Sales         HR-107          Denied
# 1             Remote   Operations         HR-101          Denied
# 2             Hybrid  Engineering         HR-103        Approved
# 3            On-site   Operations         HR-104          Denied
# 4             Hybrid   Operations         HR-104        Approved
#
#          denial_reason  days_to_implement  retained_6mo
# 0       Undue Hardship                NaN             0
# 1  Alternative Offered                NaN             0
# 2                  NaN               16.0             1
# 3       Undue Hardship                NaN             0
# 4                  NaN               19.0             1

# %%
df.tail()
# Out:
#     request_id     disability_category accommodation_category  \
# 255   REQ-1255  Cognitive/Neurological   Assistive technology
# 256   REQ-1256       Physical/Mobility  Schedule modification
# 257   REQ-1257         Chronic Medical   Assistive technology
# 258   REQ-1258                 Sensory   Assistive technology
# 259   REQ-1259                 Sensory    Policy modification
#
#      employee_tenure_years  hourly_wage_usd  has_college_degree  \
# 255                    1.4            27.95                   1
# 256                   19.4            19.92                   1
# 257                    2.4            22.72                   0
# 258                    3.4            16.31                   1
# 259                    2.4            25.65                   1
#
#      is_cost_incurred  accommodation_cost_usd request_severity_level  \
# 255                 0                     0.0                    Low
# 256                 0                     0.0                 Medium
# 257                 0                     0.0                   High
# 258                 0                     0.0                    Low
# 259                 0                     0.0                    Low
#
#     remote_work_status        department hr_reviewer_id approval_status  \
# 255             Hybrid       Engineering         HR-107          Denied
# 256             Hybrid           Finance         HR-107        Approved
# 257            On-site           Finance         HR-103        Approved
# 258            On-site  Customer Support         HR-106        Approved
# 259            On-site  Customer Support         HR-108        Approved
#
#              denial_reason  days_to_implement  retained_6mo
# 255  Lack of Documentation                NaN             1
# 256                    NaN                7.0             1
# 257                    NaN               32.0             1
# 258                    NaN                5.0             1
# 259                    NaN                2.0             1

# %%
df.sample(5, random_state=42)
# Out:
#     request_id     disability_category accommodation_category  \
# 30    REQ-1030  Cognitive/Neurological   Assistive technology
# 181   REQ-1181  Cognitive/Neurological  Schedule modification
# 223   REQ-1223           Mental Health    Policy modification
# 185   REQ-1185           Mental Health     Physical workspace
# 211   REQ-1211           Mental Health  Schedule modification
#
#      employee_tenure_years  hourly_wage_usd  has_college_degree  \
# 30                     1.9            33.68                   1
# 181                    8.1            27.71                   1
# 223                    5.0            18.26                   0
# 185                    3.3            22.43                   1
# 211                    3.9            21.87                   0
#
#      is_cost_incurred  accommodation_cost_usd request_severity_level  \
# 30                  0                    0.00                    Low
# 181                 0                    0.00                 Medium
# 223                 1                   95.48                    Low
# 185                 1                 1322.50                 Medium
# 211                 0                    0.00                    Low
#
#     remote_work_status        department hr_reviewer_id     approval_status  \
# 30              Hybrid        Operations         HR-110  Partially Approved
# 181            On-site  Customer Support         HR-102            Approved
# 223             Remote             Sales         HR-102              Denied
# 185            On-site       Engineering         HR-103              Denied
# 211            On-site             Sales         HR-107  Partially Approved
#
#              denial_reason  days_to_implement  retained_6mo
# 30                     NaN                3.0             1
# 181                    NaN               49.0             1
# 223  Lack of Documentation                NaN             1
# 185         Undue Hardship                NaN             1
# 211                    NaN               31.0             1
